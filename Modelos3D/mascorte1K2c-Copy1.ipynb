# %%
import gempy as gp 
import numpy as np 
import matplotlib.pyplot as plt
import warnings
# Out:
# No module named 'osgeo'
# WARN: Could not locate executable g77
# WARN: Could not locate executable f77
# WARN: Could not locate executable ifort
# WARN: Could not locate executable ifl
# WARN: Could not locate executable f90
# WARN: Could not locate executable DF
# WARN: Could not locate executable efl
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\numpy\distutils\system_info.py:2159: UserWarning:
#     Optimized (vendor) Blas libraries are not found.
#     Falls back to netlib Blas library which has worse performance.
#     A better performance should be easily gained by switching
#     Blas library.
#   if self._calc_info(blas):
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\numpy\distutils\system_info.py:2159: UserWarning:
#     Blas (http://www.netlib.org/blas/) libraries not found.
#     Directories to search for the libraries can be specified in the
#     numpy/distutils/site.cfg file (section [blas]) or by setting
#     the BLAS environment variable.
#   if self._calc_info(blas):
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\numpy\distutils\system_info.py:2159: UserWarning:
#     Blas (http://www.netlib.org/blas/) sources not found.
#     Directories to search for the sources can be specified in the
#     numpy/distutils/site.cfg file (section [blas_src]) or by setting
#     the BLAS_SRC environment variable.
#   if self._calc_info(blas):

# %%
geo_model = gp.create_model('Zona1')
geo_model = gp.init_data(geo_model,
                         extent = [14100, 23000, 0, 1700, -4000, 150],
                         resolution= [100,100,100], path_o="ortK2c.txt",
                          path_i="supk2c.txt")
# Out:
# Active grids: ['regular']

# %%
geo_model.surface_points
# Out:
#               X     Y          Z    smooth              surface
# 0    14042.0000     0  -960.0000  0.000002               E1E2sc
# 1    14175.0000     0  -934.0000  0.000002               E1E2sc
# 2    14711.0000     0 -1070.0000  0.000002               E1E2sc
# 3    15349.0000     0 -1203.0000  0.000002               E1E2sc
# 4    16125.0000     0 -1333.0000  0.000002               E1E2sc
# 5    16699.0000     0 -1374.0000  0.000002               E1E2sc
# 6    17161.0000     0 -1374.0000  0.000002               E1E2sc
# 7    17917.0000     0 -1374.0000  0.000002               E1E2sc
# 8    18141.0000     0 -1288.0000  0.000002               E1E2sc
# 9    18318.0000     0 -1147.0000  0.000002               E1E2sc
# 10   17892.0000     0  -926.0000  0.000002               E1E2sc
# 11   17639.0000     0  -729.0000  0.000002               E1E2sc
# 12   17924.0000     0  -810.0000  0.000002               E1E2sc
# 13   18058.5135     0  -848.2302  0.000002               E1E2sc
# 14   18407.0000     0  -808.0000  0.000002               E1E2sc
# 15   18847.0000     0  -665.0000  0.000002               E1E2sc
# 16   19405.0000     0  -445.0000  0.000002               E1E2sc
# 17   19298.0000     0  -371.0000  0.000002               E1E2sc
# 18   19519.0000     0  -287.0000  0.000002               E1E2sc
# 19   19725.0000     0  -182.0000  0.000002               E1E2sc
# 20   19832.0000     0  -103.0000  0.000002               E1E2sc
# 21   19738.0000     0   -22.0000  0.000002               E1E2sc
# 22   19630.0000     0    92.0000  0.000002               E1E2sc
# 23   14042.0000  1000  -960.0000  0.000002               E1E2sc
# 24   14175.0000  1000  -934.0000  0.000002               E1E2sc
# 25   14711.0000  1000 -1070.0000  0.000002               E1E2sc
# 26   15349.0000  1000 -1203.0000  0.000002               E1E2sc
# 27   16125.0000  1000 -1333.0000  0.000002               E1E2sc
# 290  19202.0000  1000 -1529.0000  0.000002               Falla3
# 291  19640.4801  1000 -1374.3494  0.000002               Falla3
# 292  20105.0000  1000 -1177.0000  0.000002               Falla3
# 293  20588.2656  1000  -971.6866  0.000002               Falla3
# 294  20951.0000  1000  -777.0000  0.000002               Falla3
# 295  21322.0000  1000  -491.0000  0.000002               Falla3
# 296  21706.0166  1000  -194.9656  0.000002               Falla3
# 297  21884.0000  1000   114.0000  0.000002               Falla3
# 247  16755.0000     0   113.0000  0.000002       Falla Huamanga
# 248  17038.0000     0  -220.0000  0.000002       Falla Huamanga
# 249  17498.0000     0  -613.0000  0.000002       Falla Huamanga
# 250  17639.0000     0  -729.0000  0.000002       Falla Huamanga
# 251  17892.0000     0  -926.0000  0.000002       Falla Huamanga
# 252  18318.0000     0 -1147.0000  0.000002       Falla Huamanga
# 253  18907.0000     0 -1405.0000  0.000002       Falla Huamanga
# 254  19037.9719     0 -1462.3697  0.000002       Falla Huamanga
# 298  16755.0000  1000   113.0000  0.000002       Falla Huamanga
# 299  17038.0000  1000  -220.0000  0.000002       Falla Huamanga
# 300  17498.0000  1000  -613.0000  0.000002       Falla Huamanga
# 301  17639.0000  1000  -729.0000  0.000002       Falla Huamanga
# 302  17892.0000  1000  -926.0000  0.000002       Falla Huamanga
# 303  18318.0000  1000 -1147.0000  0.000002       Falla Huamanga
# 304  18907.0000  1000 -1405.0000  0.000002       Falla Huamanga
# 305  19037.9719  1000 -1462.3697  0.000002       Falla Huamanga

# %%
geo_model.surfaces
# Out:
#                 surface          series  order_surfaces    color  id
# 0                E1E2sc  Default series               1  #015482   1
# 1                   K2c  Default series               2  #9f0052   2
# 2               E1E2sc2  Default series               3  #ffbe00   3
# 3                  E2ma  Default series               4  #728f02   4
# 4               E1E2sc3  Default series               5  #443988   5
# 5                  E2ch  Default series               6  #ff3f20   6
# 6                Falla1  Default series               7  #5DA629   7
# 7   Falla de las Bongas  Default series               8  #4878d0   8
# 8       Falla Principal  Default series               9  #ee854a   9
# 9                Falla3  Default series              10  #6acc64  10
# 10       Falla Huamanga  Default series              11  #d65f5f  11
# 11             basement        Basement               1  #956cb4  12

# %%
geo_model.orientations
# Out:
#              X     Y          Z           G_x           G_y       G_z  smooth              surface
# 7   18847.0000     0  -665.0000 -3.090170e-01  9.999432e-13  0.951057    0.01               E1E2sc
# 8   17161.0000     0 -1374.0000  1.000000e-12  1.000000e-12  1.000000    0.01               E1E2sc
# 9   19519.0000     0  -287.0000 -4.539905e-01  9.999166e-13  0.891007    0.01               E1E2sc
# 10  17924.0000     0  -810.0000  2.756374e-01  1.000017e-12  0.961262    0.01               E1E2sc
# 11  17892.0000     0  -926.0000 -5.877853e-01  9.999640e-13 -0.809017    0.01               E1E2sc
# 45  18847.0000  1000  -665.0000 -3.090170e-01  9.999432e-13  0.951057    0.01               E1E2sc
# 46  19519.0000  1000  -287.0000 -4.539905e-01  9.999166e-13  0.891007    0.01               E1E2sc
# 47  17924.0000  1000  -810.0000  2.756374e-01  1.000017e-12  0.961262    0.01               E1E2sc
# 67  17639.0000  1000  -729.0000  5.877853e-01  1.000036e-12  0.809017    0.01       Falla Huamanga
# 68  19037.9719  1000 -1462.3697 -6.427876e-01  9.998819e-13  0.766044    0.01       Falla Huamanga
# 69  20501.0000  1000  -107.0000 -6.427876e-01  9.998819e-13  0.766044    0.01       Falla Huamanga

# %%
gp.map_stack_to_surfaces(geo_model,
                         {"Fault_Series1": ('Falla1'),
                          "Fault_Series2": ('Falla de las Bongas'),
                          "Fault_Series3": ('Falla Huamanga'),
                          "Fault_Series4": ('Falla3'),
                          "Fault_Series5": ('Falla Principal'),
                         "Strat_Series2": ('E1E2sc','K2c'),
                         "Strat_Series1": ('E1E2sc2'),
                         "Strat_Series0": ('E2ma'),
                         "Strat_Series3": ('E1E2sc3'),
                         "Strat_Series4": ('K2c2')},
                         remove_unused_series=True)
# Out:
#                 surface          series  order_surfaces    color  id
# 5                  E2ch  Default series               1  #ff3f20   1
# 6                Falla1   Fault_Series1               1  #5DA629   2
# 7   Falla de las Bongas   Fault_Series2               1  #4878d0   3
# 10       Falla Huamanga   Fault_Series3               1  #d65f5f   4
# 9                Falla3   Fault_Series4               1  #6acc64   5
# 8       Falla Principal   Fault_Series5               1  #ee854a   6
# 0                E1E2sc   Strat_Series2               1  #015482   7
# 1                   K2c   Strat_Series2               2  #9f0052   8
# 2               E1E2sc2   Strat_Series1               1  #ffbe00   9
# 3                  E2ma   Strat_Series0               1  #728f02  10
# 4               E1E2sc3   Strat_Series3               1  #443988  11
# 11             basement        Basement               1  #956cb4  12

# %%
geo_model.stack
# Out:
#                 order_series BottomRelation  isActive  isFault  isFinite
# Default series             1        Erosion      True    False     False
# Fault_Series1              2        Erosion      True    False     False
# Fault_Series2              3        Erosion      True    False     False
# Fault_Series3              4        Erosion      True    False     False
# Fault_Series4              5        Erosion      True    False     False
# Fault_Series5              6        Erosion      True    False     False
# Strat_Series2              7        Erosion      True    False     False
# Strat_Series1              8        Erosion      True    False     False
# Strat_Series0              9        Erosion      True    False     False
# Strat_Series3             10        Erosion      True    False     False
# Basement                  11        Erosion     False    False     False

# %%
geo_model.set_is_fault(['Fault_Series1','Fault_Series2','Fault_Series3','Fault_Series4','Fault_Series5'])
# Out:
# Fault colors changed. If you do not like this behavior, set change_color to False.
# Fault colors changed. If you do not like this behavior, set change_color to False.
#                 order_series BottomRelation  isActive  isFault  isFinite
# Default series             1        Erosion      True    False     False
# Fault_Series1              2          Fault      True     True     False
# Fault_Series2              3          Fault      True     True     False
# Fault_Series3              4          Fault      True     True     False
# Fault_Series4              5          Fault      True     True     False
# Fault_Series5              6          Fault      True     True     False
# Strat_Series2              7        Erosion      True    False     False
# Strat_Series1              8        Erosion      True    False     False
# Strat_Series0              9        Erosion      True    False     False
# Strat_Series3             10        Erosion      True    False     False
# Basement                  11        Erosion     False    False     False

# %%
geo_model.faults.faults_relations_df
# Out:
#                 Default series  Fault_Series1  Fault_Series2  Fault_Series3
# Default series           False          False          False          False  \
# Fault_Series1            False          False          False          False
# Fault_Series2            False          False          False          False
# Fault_Series3            False          False          False          False
# Fault_Series4            False          False          False          False
# Fault_Series5            False          False          False          False
# Strat_Series2            False          False          False          False
# Strat_Series1            False          False          False          False
# Strat_Series0            False          False          False          False
# Strat_Series3            False          False          False          False
# Basement                 False          False          False          False
#
#                 Fault_Series4  Fault_Series5  Strat_Series2  Strat_Series1
# Default series          False          False          False          False  \
# Fault_Series1           False          False           True           True
# Fault_Series2           False          False           True           True
# Fault_Series3           False          False           True           True
# Fault_Series4           False          False           True           True
# Fault_Series5           False          False           True           True
# Strat_Series2           False          False          False          False
# Strat_Series1           False          False          False          False
# Strat_Series0           False          False          False          False
# Strat_Series3           False          False          False          False
# Basement                False          False          False          False
#
#                 Strat_Series0  Strat_Series3  Basement
# Default series          False          False     False
# Fault_Series1            True           True      True
# Fault_Series2            True           True      True
# Fault_Series3            True           True      True
# Fault_Series4            True           True      True
# Fault_Series5            True           True      True
# Strat_Series2           False          False     False
# Strat_Series1           False          False     False
# Strat_Series0           False          False     False
# Strat_Series3           False          False     False
# Basement                False          False     False

# %%
geo_model.grid
# Out:
# Grid Object. Values:
# array([[ 1.41445e+04,  8.50000e+00, -3.97925e+03],
#        [ 1.41445e+04,  8.50000e+00, -3.93775e+03],
#        [ 1.41445e+04,  8.50000e+00, -3.89625e+03],
#        ...,
#        [ 2.29555e+04,  1.69150e+03,  4.62500e+01],
#        [ 2.29555e+04,  1.69150e+03,  8.77500e+01],
#        [ 2.29555e+04,  1.69150e+03,  1.29250e+02]])

# %%
gp.set_interpolator(
    geo_model,
    output=['geology'],
    theano_optimizer='fast compile')
# Out:
# Setting kriging parameters to their default values.
# Compiling aesara function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  5
# Compilation Done!
# Kriging values:
#                                              values
# range                                  9966.067429
# $C_o$                               2364821.428571
# drift equations  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
gp.get_data(geo_model, 'orientations')
# Out:
#              X     Y          Z           G_x           G_y       G_z  smooth
# 26  21706.0166     0  -194.9656  7.660444e-01  1.000141e-12 -0.642788    0.01  \
# 27  22445.0000     0  -552.4379  1.000000e-12  1.000000e-12  1.000000    0.01
# 28  21858.0000     0  -474.0000  2.249511e-01  1.000014e-12  0.974370    0.01
# 62  21706.0166  1000  -194.9656  7.660444e-01  1.000141e-12 -0.642788    0.01
# 63  21858.0000  1000  -474.0000  2.249511e-01  1.000014e-12  0.974370    0.01
# ..         ...   ...        ...           ...           ...       ...     ...
# 24  17907.0000     0 -2543.0000  6.156615e-01  1.000038e-12  0.788011    0.01
# 25  24166.1518     0 -2790.2671  1.000000e-12  1.000000e-12  1.000000    0.01
# 59  18273.0000  1000 -2073.0000  6.156615e-01  1.000113e-12 -0.788011    0.01
# 60  19202.0000  1000 -1529.0000  3.583679e-01  1.000066e-12 -0.933580    0.01
# 61  17907.0000  1000 -2543.0000  6.156615e-01  1.000038e-12  0.788011    0.01
#
#     surface
# 26     E2ch
# 27     E2ch
# 28     E2ch
# 62     E2ch
# 63     E2ch
# ..      ...
# 24  E1E2sc3
# 25  E1E2sc3
# 59  E1E2sc3
# 60  E1E2sc3
# 61  E1E2sc3
#
# [72 rows x 8 columns]

# %%
surfaces = geo_model.surfaces
surfaces.colors.change_colors()
# Out:
# Click to select new colors.
# VBox(children=(ColorPicker(value='#015482', description='E1E2sc'), ColorPicker(value='#9f0052', description='K…

# %%
# Configurar colores para las superficies
geo_model.surfaces.colors.change_colors({
    'E1E2sc': '#df8f19',
    'K2c': '#2bb535',
    'E1E2sc2': '#df8f19',
    'E1E2sc3': '#df8f19',
    'E2ma': '#fca237',
    'basement': '#ffffff',
    'E2ch': '#eca41e'
})

# %%
plot = gp.plot_2d(geo_model, show_lith=False, show_boundaries=False)
plt.savefig('data-cansona.png')
plt.show()
# Out:
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gp.get_data(geo_model, 'kriging')
# Out:
#                                             values
# range                                  9966.067429
# $C_o$                               2364821.428571
# drift equations  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
sol = gp.compute_model(geo_model)
# Out:
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\aesara\tensor\slinalg.py:390: LinAlgWarning: Ill-conditioned matrix (rcond=1.7649e-30): result may not be accurate.
#   outputs[0][0] = scipy.linalg.solve(
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\aesara\tensor\slinalg.py:390: LinAlgWarning: Ill-conditioned matrix (rcond=7.05456e-30): result may not be accurate.
#   outputs[0][0] = scipy.linalg.solve(

# %%
geo_model.solutions
# Out:
# Lithology ids
#   [12. 12. 12. ...  1.  1.  1.]

# %%
gp.plot_2d(geo_model, show_data=True, cell_number=0, legend=False)
plt.savefig('cansonacentro.png')
plt.show()
# Out:
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gp.plot_2d(geo_model, show_block=True, series_n=5, show_lith=False)
plt.show()
# Out:
# C:\Users\silva\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gp.plot_2d(geo_model, series_n=4, show_data=False, show_scalar=True, show_lith=False, cell_number=0)
plt.savefig('CE_mas_falla3.png')
plt.show()

# %%
gp.plot_2d(geo_model, series_n=6, show_data=False, show_scalar=True, show_lith=False, cell_number=20)
plt.savefig('CE_mas_capas.png')
plt.show()

# %%
gpv = gp.plot_3d(geo_model, image=False, plotter_type='background', show_data=True, show_lith=True, kwargs_plot_structured_grid={'opacity': 0.5})

# %%
geo_model.surfaces
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 geo_model.surfaces
#
# NameError: name 'geo_model' is not defined

# %%
#ASIGNAR PROPIEDADES FISICAS
#geo_model.add_surface_values([3200, 4000, 4000, 4000, 4000, 4000, 4300, 3100, 4300, 4200, 4300, 5500], ['vp'])  #m/s vp
geo_model.add_surface_values([2.54, 2, 2, 2, 2, 2, 2.6, 2.4, 2.6, 2.5, 2.6, 3], ['density'])  #g/cm3 density
geo_model.surfaces

# %%
# Set up plotter
p3d = gp.plot_3d(geo_model, notebook=True)
# Plot data points and orientations
p3d.plot_data()

# Compute the model. Note that a solution is returned. We will use this later
sol = gp.compute_model(geo_model)

# Plot the surfaces
p3d.plot_surfaces()
# Plot the lithological units
p3d.plot_structured_grid('lith')

# %%
sol.values_matrix

# %%
# Reshaping our data to the shape required by Devito
import numpy as np
shape = [100, 100, 100]
reshaped = np.reshape(sol.values_matrix, shape, order='C')
reshaped.shape

# %%
import matplotlib.pyplot as plt

# Take the center slice in the x direction
# Remember that in Devito, indexing convention is [x, y, z] (need to flip for correct imshow display)
plt.imshow(reshaped[:,5,:].T, cmap='viridis', origin='lower')
plt.title('Densidad (g/cm3)')
plt.colorbar(location="bottom", shrink=0.5)
plt.savefig('dencentral.png', dpi=300)
plt.show()

# %%
gp.set_interpolator(geo_model,
                    compile_theano=True,
                    theano_optimizer='fast_compile',
                    )

# %%
ver, sim = gp.get_surfaces(geo_model)
gpv = gp.plot_3d(geo_model, image=False, show_data=False, plotter_type='basic')

# %%
geo_model.surface_points

# %%
indices_bool = geo_model.surface_points.df['surface'].isin(['E1E2sc','K2c','E1E2sc2','E2ma','E1E2sc3','E2ch'])

# %%
indices = geo_model.surface_points.df.index[indices_bool]
indices

# %%
Z_init = geo_model.surface_points.df.loc[indices, 'Z'].copy()
Z_init

# %%
len(Z_init[0:46]) + len(Z_init[46:86]) + len(Z_init[86:130])+ len(Z_init[130:150])+ len(Z_init[150:184])+ len(Z_init[184:204])

# %%
Z_var = np.random.normal(0, 30, size=6)
Z_var
Z_loc = np.hstack([Z_init[0:46] + Z_var[0],
                       Z_init[46:86] + Z_var[1],
                       Z_init[86:130] + Z_var[2],
                       Z_init[130:150] + Z_var[3],
                       Z_init[150:184] + Z_var[4],
                       Z_init[184:204] + Z_var[5]])
Z_loc

# %%
def sample(silent=True):
    Z_var = np.random.normal(0, 30, size=6)
    Z_loc = np.hstack([Z_init[0:46] + Z_var[0],
                       Z_init[46:86] + Z_var[1],
                       Z_init[86:130] + Z_var[2],
                       Z_init[130:150] + Z_var[3],
                       Z_init[150:184] + Z_var[4],
                       Z_init[184:204] + Z_var[5]])
    
    if silent:
        geo_model.modify_surface_points(indices, Z=Z_loc)
        gp.compute_model(geo_model)
    else:
        # Crear un objeto de trazado utilizando gp.plot_2d
        plot_object = gp.plot_2d(geo_model)
        
        # Pasar el objeto de trazado como argumento a modify_surface_points
        geo_model.modify_surface_points(indices, Z=Z_loc, plot_object=plot_object)
    
    return geo_model.solutions.lith_block

# %%
lith_blocks = np.array([])
n_iterations = 10  # Número de iteraciones que deseas

for i in range(n_iterations):
    lith_blocks = np.append(lith_blocks, sample())

# %%
lith_blocks.shape

# %%
lith_blocks = lith_blocks.reshape(n_iterations, -1)
lith_blocks.shape, lith_blocks

# %%
from gempy.bayesian.fields import compute_prob, calculate_ie_masked
prob_block = compute_prob(lith_blocks)

# %%
layer = 1
p2dp = gp.plot_2d(geo_model,
                  show_lith=False, show_boundaries=False,
                  show_data=False, cell_number=0,
                  regular_grid=prob_block[layer],
                  kwargs_regular_grid={'cmap': 'viridis', 'norm': None})

prob_min = prob_block[layer].min()  # Valor mínimo de probabilidad
prob_max = prob_block[layer].max()  # Valor máximo de probabilidad

# Crear algunos datos de muestra
data = np.random.rand(50, 50)

# Crear un gráfico con imshow y obtener el objeto mappable
mappable = plt.imshow(data, cmap='viridis')

# Agregar un título a la imagen
plt.title('')

# Crear una barra de color usando el objeto mappable
colorbar = plt.colorbar(mappable, shrink=0.3)

# Editar los números de los ticks de la barra de color
colorbar.set_ticks([0, 1])  # Definir las ubicaciones de los ticks
#colorbar.set_ticklabels(['Bajo', 'Medio', 'Alto'])  # Definir las etiquetas de los ticks
colorbar.set_label('Probabilidad de la capa')  # Definir la etiqueta

# Guardar la figura después de mostrarla
plt.savefig('.png', dpi=300)
plt.show()
